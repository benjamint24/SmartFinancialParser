# %%
# EDA libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('../datasets/synthetic_transactions_clean.csv')

# Quick sanity checks for dataframe
#print("Shape:", df.shape)
#print("\nColumns:\n", df.columns.tolist())

# Show first 5 rows
df.head()
# Out:
#          date      merchant   amount
# 0  2019-12-13        COSTCO  1913.00
# 1  2024-03-13  OLIVE GARDEN  2124.47
# 2  2020-09-08        LOWE'S  2000.32
# 3  2020-07-28        AMAZON  2432.76
# 4  2021-12-01       NETFLIX  2171.62

# %%
# grouping by merchants to find top 5 merchants by average amount spent
merchant_avg = (
    df
    .groupby("merchant", as_index=False)["amount"]
    .mean()
    .sort_values(by="amount", ascending=False)
)

merchant_avg.head()
# Out:
#        merchant       amount
# 6        GOOGLE  2281.840000
# 12      NETFLIX  2171.620000
# 9        LOWE'S  2064.523333
# 18  SUSHI HOUSE  1964.870000
# 11    MCDONALDS  1952.436667

# %%
plt.figure(figsize=(14, 6))

sns.barplot(
    data=merchant_avg,
    x="merchant",
    y="amount"
)

plt.xticks(rotation=45, ha="right")
plt.xlabel("Merchant")
plt.ylabel("Total Transaction Amount")
plt.title("Total Transaction Amount by Merchant")
# Out:
# Text(0.5, 1.0, 'Total Transaction Amount by Merchant')

# %% [markdown]
# Top Spender on average is LOWE'S

# %%
# same thing but group by total
merchant_total = (
    df
    .groupby("merchant", as_index=False)["amount"]
    .sum()
    .sort_values(by="amount", ascending=False)
)

merchant_total.head()
# Out:
#      merchant   amount
# 20       UBER  9223.36
# 9      LOWE'S  6193.57
# 11  MCDONALDS  5857.31
# 15      SHELL  5635.17
# 1      AMAZON  5049.86

# %% [markdown]
# Top Spender in total is Instacart

# %%
plt.figure(figsize=(14, 6))

sns.barplot(
    data=merchant_total,
    x="merchant",
    y="amount"
)

plt.xticks(rotation=45, ha="right")
plt.xlabel("Merchant")
plt.ylabel("Total Transaction Amount")
plt.title("Total Transaction Amount by Merchant")
# Out:
# Text(0.5, 1.0, 'Total Transaction Amount by Merchant')

# %%
CLEAN_FILE = "../datasets/synthetic_transactions_clean.csv"


def analysis_demo():
    print("\n=== TRANSACTION ANALYSIS DEMO ===\n")

    # Load cleaned data
    try:
        df = pd.read_csv(CLEAN_FILE)
    except FileNotFoundError:
        print(f"Could not find cleaned file at: {CLEAN_FILE}")
        print("Run the cleaning step first.")
        return

    # Quick sanity checks
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")
    print("\nColumns:", df.columns.tolist())

    print("\n--- Data Preview (first 5 rows) ---")
    print(df.head())

    # Top merchants by average amount
    merchant_avg = (
        df
        .groupby("merchant", as_index=False)["amount"]
        .mean()
        .sort_values(by="amount", ascending=False)
    )

    # Top merchants by total amount
    merchant_total = (
        df
        .groupby("merchant", as_index=False)["amount"]
        .sum()
        .sort_values(by="amount", ascending=False)
    )

    top_avg = merchant_avg.iloc[0]
    top_total = merchant_total.iloc[0]

    print("\nMost expensive merchant on average: ")
    print(top_avg["merchant"])

    print("Most expensive merchant in total: ")
    print(top_total["merchant"])

    print("\n--- Top 5 Merchants by AVERAGE Amount ---")
    print(merchant_avg.head(5))

    print("\n--- Top 5 Merchants by TOTAL Amount ---")
    print(merchant_total.head(5))

    print("\nAnalysis complete.\n")

# %%
if __name__ == "__main__":
    analysis_demo()
# Out:
# === TRANSACTION ANALYSIS DEMO ===
#
# Shape: 56 rows x 3 columns
#
# Columns: ['date', 'merchant', 'amount']
#
# --- Data Preview (first 5 rows) ---
#          date      merchant   amount
# 0  2019-12-13        COSTCO  1913.00
# 1  2024-03-13  OLIVE GARDEN  2124.47
# 2  2020-09-08        LOWE'S  2000.32
# 3  2020-07-28        AMAZON  2432.76
# 4  2021-12-01       NETFLIX  2171.62
#
# Most expensive merchant on average:
# GOOGLE
# Most expensive merchant in total:
# UBER
#
# --- Top 5 Merchants by AVERAGE Amount ---
#        merchant       amount
# 6        GOOGLE  2281.840000
# 12      NETFLIX  2171.620000
# 9        LOWE'S  2064.523333
# 18  SUSHI HOUSE  1964.870000
# 11    MCDONALDS  1952.436667
#
# --- Top 5 Merchants by TOTAL Amount ---
#      merchant   amount
# 20       UBER  9223.36
# 9      LOWE'S  6193.57
# 11  MCDONALDS  5857.31
# 15      SHELL  5635.17
# 1      AMAZON  5049.86
#
# Analysis complete.
