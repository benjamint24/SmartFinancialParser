# %%
# EDA libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# for matplotlib to run inline so i gont have to do .show() all the time
# %matplotlib inline

df = pd.read_csv('../datasets/synthetic_transactions_clean.csv')

# Quick sanity checks for dataframe
print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())

# Show first 5 rows
df.head()
# Out:
# Shape: (1000, 3)
#
# Columns:
#  ['date', 'merchant', 'amount']
#          date   merchant   amount
# 0  2021-09-26     AMAZON     1.00
# 1  2024-08-11  STARBUCKS  2395.00
# 2  2025-01-09     AIRBNB  1053.93
# 3  2019-09-22      SHELL  1698.42
# 4  2020-01-19   DOORDASH  1613.00

# %%
# grouping by merchants to find top 5 merchants by average amount spent
merchant_avg = (
    df
    .groupby("merchant", as_index=False)["amount"]
    .mean()
    .sort_values(by="amount", ascending=False)
)

merchant_avg.head()
# Out:
#          merchant       amount
# 13         LOWE'S  1505.497857
# 15         MACY'S  1504.198235
# 19  PANDA EXPRESS  1405.990000
# 4    CAR WASH PRO  1389.531333
# 25           UBER  1270.832105

# %%
plt.figure(figsize=(14, 6))

sns.barplot(
    data=merchant_avg,
    x="merchant",
    y="amount"
)

plt.xticks(rotation=45, ha="right")
plt.xlabel("Merchant")
plt.ylabel("Total Transaction Amount")
plt.title("Total Transaction Amount by Merchant")
# Out:
# Text(0.5, 1.0, 'Total Transaction Amount by Merchant')

# %% [markdown]
# Top Spender on average is LOWE'S

# %%
# same thing but group by total
merchant_total = (
    df
    .groupby("merchant", as_index=False)["amount"]
    .sum()
    .sort_values(by="amount", ascending=False)
)

merchant_total.head()
# Out:
#      merchant    amount
# 12  INSTACART  83615.74
# 25       UBER  72437.43
# 22  STARBUCKS  69337.65
# 21    SPOTIFY  67439.21
# 7      COSTCO  64277.78

# %% [markdown]
# Top Spender in total is Instacart

# %%
plt.figure(figsize=(14, 6))

sns.barplot(
    data=merchant_total,
    x="merchant",
    y="amount"
)

plt.xticks(rotation=45, ha="right")
plt.xlabel("Merchant")
plt.ylabel("Total Transaction Amount")
plt.title("Total Transaction Amount by Merchant")
# Out:
# Text(0.5, 1.0, 'Total Transaction Amount by Merchant')

# %%
CLEAN_FILE = "../datasets/synthetic_transactions_clean.csv"


def analysis_demo():
    print("\n=== TRANSACTION ANALYSIS DEMO ===\n")

    # Load cleaned data
    try:
        df = pd.read_csv(CLEAN_FILE)
    except FileNotFoundError:
        print(f"Could not find cleaned file at: {CLEAN_FILE}")
        print("Run the cleaning step first.")
        return

    # Quick sanity checks
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")
    print("\nColumns:", df.columns.tolist())

    print("\n--- Data Preview (first 5 rows) ---")
    print(df.head())

    # Top merchants by average amount
    merchant_avg = (
        df
        .groupby("merchant", as_index=False)["amount"]
        .mean()
        .sort_values(by="amount", ascending=False)
    )

    # Top merchants by total amount
    merchant_total = (
        df
        .groupby("merchant", as_index=False)["amount"]
        .sum()
        .sort_values(by="amount", ascending=False)
    )

    print("\n--- Top 5 Merchants by AVERAGE Amount ---")
    print(merchant_avg.head(5))

    print("\n--- Top 5 Merchants by TOTAL Amount ---")
    print(merchant_total.head(5))

    # Optional: quick plots
    choice = input("\nShow quick amount / merchant plots? (y/n): ").strip().lower()

    if choice == "y":
        plt.figure(figsize=(14, 6))

        sns.barplot(
            data=merchant_avg,
            x="merchant",
            y="amount"
        )
        
        plt.xticks(rotation=45, ha="right")
        plt.xlabel("Merchant")
        plt.ylabel("Total Transaction Amount")
        plt.title("Total Transaction Amount by Merchant")

        plt.figure(figsize=(14, 6))

        sns.barplot(
            data=merchant_total,
            x="merchant",
            y="amount"
        )
        
        plt.xticks(rotation=45, ha="right")
        plt.xlabel("Merchant")
        plt.ylabel("Total Transaction Amount")
        plt.title("Total Transaction Amount by Merchant")
    else:
        print("Skipping plots.")

    print("\nAnalysis complete.\n")

# %%
analysis_demo()
# Out:
# === TRANSACTION ANALYSIS DEMO ===
#
# Shape: 230 rows x 3 columns
#
# Columns: ['date', 'merchant', 'amount']
#
# --- Data Preview (first 5 rows) ---
#          date      merchant   amount
# 0  2024-07-31      BEST BUY  1055.67
# 1  2024-09-15      DOORDASH   960.88
# 2  2025-10-07     STARBUCKS  1885.88
# 3  2019-10-14  CAR WASH PRO   523.81
# 4  2024-04-22   SUSHI HOUSE   603.89
#
# --- Top 5 Merchants by AVERAGE Amount ---
#          merchant       amount
# 15         MACY'S  2010.397500
# 20          SHELL  1634.354286
# 3        BEST BUY  1526.166000
# 19  PANDA EXPRESS  1481.182500
# 13         LOWE'S  1349.480000
#
# --- Top 5 Merchants by TOTAL Amount ---
#      merchant    amount
# 16  MCDONALDS  18697.03
# 17    NETFLIX  17387.23
# 9      GOOGLE  17053.09
# 0      AIRBNB  16869.89
# 2       APPLE  16637.36
# Show quick amount / merchant plots? (y/n):  n
# Skipping plots.
#
# Analysis complete.
