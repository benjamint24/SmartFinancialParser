# %%
import time
import datacreation
import datacleaning
import dataanalysis


def main():
    while True:
        print("\n==============================")
        print("Welcome to Benjamin's data parser!")
        print("==============================\n")

        # 1) CREATE
        if datacreation.creation_demo() is False:
            break

        # 2) CLEAN
        if datacleaning.cleaning_demo() is False:
            break

        #delay to give user time to see clean before analysis
        time.sleep(3)

        # 3) ANALYZE
        dataanalysis.analysis_demo()

        # REPEAT
        print("\nRun the entire pipeline again with new data? (y/n)")
        choice = input(">> ").strip().lower()

        if choice != "y":
            break
    
    #breaks either due to done with parser or error
    print("\nExiting pipeline. Goodbye.")


if __name__ == "__main__":
    main()
# Out:
# Shape: (500, 3)
#
# Columns:
#  ['date', 'merchant', 'amount']
#
# ==============================
# Welcome to Benjamin's data parser!
# ==============================
#
# Enter the amount of rows of messy data to generate:
# >>  200
# Synthetic, error-filled CSV generated successfully with 200 rows.
# Now, we can clean the raw synthetic transactions file.
# Input file:  ../datasets/synthetic_transactions.csv
# Output file: ../datasets/synthetic_transactions_clean.csv
#
# Proceed with cleaning? (y/n)
# >>  y
# Total raw rows:       200
# Rows kept:            200
# Date parse errors:    0
# Amount parse errors:  0
# Unmapped merchants:   0
# Cleaning completed successfully.
#
# === TRANSACTION ANALYSIS DEMO ===
#
# Shape: 200 rows x 3 columns
#
# Columns: ['date', 'merchant', 'amount']
#
# --- Data Preview (first 5 rows) ---
#          date merchant   amount
# 0  2023-07-13  WALMART   351.73
# 1  2019-12-23  SPOTIFY   224.72
# 2  2025-03-29    SHELL  2142.23
# 3  2024-01-28  WALMART  2249.26
# 4  2025-02-04  WALMART  2275.24
#
# Most expensive merchant on average:
# MACY'S
# Most expensive merchant in total:
# WALMART
#
# --- Top 5 Merchants by AVERAGE Amount ---
#        merchant       amount
# 14       MACY'S  1981.523333
# 0        AIRBNB  1789.271250
# 22  SUSHI HOUSE  1767.426667
# 25      WALMART  1677.835333
# 6        COSTCO  1623.101667
#
# --- Top 5 Merchants by TOTAL Amount ---
#      merchant    amount
# 25    WALMART  25167.53
# 21  STARBUCKS  20214.04
# 13       LYFT  19071.51
# 7    DOORDASH  16842.09
# 16    NETFLIX  15883.53
#
# Analysis complete.
#
#
# Run the entire pipeline again with new data? (y/n)
# >>  n
# Exiting pipeline. Goodbye.
